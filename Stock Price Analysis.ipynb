# %%
import numpy as np
import pandas as pd
# !pip install scikit-learn
import sklearn

# %%
stock = pd.read_csv('stock_prices.csv')

# %%
stock
# Out:
#               Date      Symbol Series Prev Close    Open    High     Low  \
# 0       2007-11-27  MUNDRAPORT     EQ      440.0   770.0  1050.0   770.0
# 1       2007-11-28  MUNDRAPORT     EQ      962.9   984.0   990.0   874.0
# 2       2007-11-29  MUNDRAPORT     EQ      893.9   909.0  914.75   841.0
# 3       2007-11-30  MUNDRAPORT     EQ      884.2   890.0   958.0   890.0
# 4       2007-12-03  MUNDRAPORT     EQ     921.55  939.75   995.0   922.0
# ...            ...         ...    ...        ...     ...     ...     ...
# 100285  2021-04-26       WIPRO     EQ      475.7   479.4  483.85   477.0
# 100286  2021-04-27       WIPRO     EQ      480.3   481.4   487.0   481.0
# 100287  2021-04-28       WIPRO     EQ     485.05  485.85   493.2  481.25
# 100288  2021-04-29       WIPRO     EQ      489.3   492.7   492.8   485.7
# 100289  2021-04-30       WIPRO     EQ     489.85   491.5   511.8   489.3
#
#           Last   Close    VWAP    Volume            Turnover    Trades  \
# ...

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100290 entries, 0 to 100289
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                100290 non-null  object
#  1   Symbol              100290 non-null  object
#  2   Series              100290 non-null  object
#  3   Prev Close          100290 non-null  object
#  4   Open                100290 non-null  object
#  5   High                100290 non-null  object
#  6   Low                 100290 non-null  object
#  7   Last                100290 non-null  object
#  8   Close               100290 non-null  object
#  9   VWAP                100290 non-null  object
#  10  Volume              100290 non-null  object
#  11  Turnover            100290 non-null  object
#  12  Trades              51596 non-null   object
#  13  Deliverable Volume  92691 non-null   object
#  14  %Deliverble         92691 non-null   object
# ...

# %%
stock['Symbol'].value_counts()
# Out:
# Symbol
# HDFCBANK      5306
# CIPLA         5306
# RELIANCE      5306
# ITC           5306
# ICICIBANK     5306
# HDFC          5306
# WIPRO         5306
# ASIANPAINT    5306
# BRITANNIA     5305
# HCLTECH       5300
# TATAMOTORS    4307
# TCS           4139
# NTPC          4088
# TATASTEEL     3851
# AXISBANK      3394
# BAJAJ-AUTO    3202
# BAJAJFINSV    3201
# INFOSYSTCH    2870
# NESTLEIND     2806
# BAJFINANCE    2624
# BAJAUTOFIN    2611
# INFY          2436
# ADANIPORTS    2299
# UTIBANK       1912
# TISCO         1455
# MUNDRAPORT    1023
# TELCO          999
# Symbol          20
# Name: count, dtype: int64

# %%
stock['Symbol'] = stock['Symbol'].replace('MUNDRAPORT', 'ADANIPORTS.NS')

# %%
stock['Symbol'] = stock['Symbol'].replace('UTIBANK', 'AXISBANK.NS')

# %%
stock['Symbol'] = stock['Symbol'].replace('TISCO', 'TATASTEEL.NS')

# %%
stock['Symbol'] = stock['Symbol'].replace('TELCO', 'TATAMOTORS.NS')

# %%
stock['Symbol'] = stock['Symbol'].replace('INFOYSTECH', 'INFY')

# %%
stock['Symbol'] = stock['Symbol'].replace('HEROHONDA', 'HEROMOTOCO.NS')

# %%
stock['Symbol'] = stock['Symbol'].replace('ADANIPORTS', 'ADANIPORTS.NS')

# %%
stock['Symbol'] = stock['Symbol'].replace('ASIANPAINT', 'ASIANPAINT.NS')
stock['Symbol'] = stock['Symbol'].replace('AXISBANK', 'AXISBANK.NS')
stock['Symbol'] = stock['Symbol'].replace('BAJAJ-AUTO', 'BAJAJ-AUTO.NS')
stock['Symbol'] = stock['Symbol'].replace('BAJAUTOFIN', 'BAJFINANCE.NS')
stock['Symbol'] = stock['Symbol'].replace('BAJFINANCE', 'BAJAJFINSV.NS')
stock['Symbol'] = stock['Symbol'].replace('BRITANNIA', 'BRITANNIA.NS')
stock['Symbol'] = stock['Symbol'].replace('CIPLA', 'CIPLA.NS')
stock['Symbol'] = stock['Symbol'].replace('HCLTECH', 'HCLTECH.NS')
stock['Symbol'] = stock['Symbol'].replace('HDFC', 'HDFCBANK.NS')
stock['Symbol'] = stock['Symbol'].replace('ICICIBANK', 'ICICIBANK.NS')
stock['Symbol'] = stock['Symbol'].replace('ITC', 'ITC.NS')
stock['Symbol'] = stock['Symbol'].replace('NESTLEIND', 'NESTLEINDIA.NS')
stock['Symbol'] = stock['Symbol'].replace('NTPC', 'NTPC.NS')
stock['Symbol'] = stock['Symbol'].replace('RELIANCE', 'RELIANCE.NS')
stock['Symbol'] = stock['Symbol'].replace('TATAMOTORS', 'TATAMOTORS.NS')
stock['Symbol'] = stock['Symbol'].replace('TATASTEEL', 'TATASTEEL.NS')
stock['Symbol'] = stock['Symbol'].replace('TCS', 'TCS.NS')
stock['Symbol'] = stock['Symbol'].replace('WIPRO', 'WIPRO.NS')
stock['Symbol'] = stock['Symbol'].replace('INFOSYSTCH', 'INFY')
stock['Symbol'] = stock['Symbol'].replace('HEROMOTOCO', 'HEROMOTOCO.NS')

# %%
#ADANIPORTS.NS    3322
#ASIANPAINT       5306
#AXISBANK         3394
#AXISBANK.NS      1912
#BAJAJ-AUTO       3202
#BAJAUTOFIN       2611
#BAJFINANCE       2624
#BRITANNIA        5305
#CIPLA            5306
#HCLTECH          5300
#HDFC             5306
#HEROMOTOCO       2408
#HEROMOTOCO.NS    2898
#ICICIBANK        5306
#INFOSYSTCH       2870
#INFY             2436
#ITC              5306
#NESTLEIND        2806
#NTPC             4088
#RELIANCE         5306
#TATAMOTORS       4307
#TATAMOTORS.NS     999
#TATASTEEL        3851
#TATASTEEL.NS     1455
#TCS              4139
#WIPRO            5306

# %%
stock.drop(columns=['Trades','Deliverable Volume','%Deliverble'],inplace=True)
stock.drop(columns=['Series'],inplace=True)

# %%
#stock['Series'].value_counts()

# %%
#stock

# %%
#stock.drop(columns=['High'],inplace=True)

# %%
stock
# Out:
#               Date         Symbol Prev Close    Open    High     Low    Last  \
# 0       2007-11-27  ADANIPORTS.NS      440.0   770.0  1050.0   770.0   959.0
# 1       2007-11-28  ADANIPORTS.NS      962.9   984.0   990.0   874.0   885.0
# 2       2007-11-29  ADANIPORTS.NS      893.9   909.0  914.75   841.0   887.0
# 3       2007-11-30  ADANIPORTS.NS      884.2   890.0   958.0   890.0   929.0
# 4       2007-12-03  ADANIPORTS.NS     921.55  939.75   995.0   922.0   980.0
# ...            ...            ...        ...     ...     ...     ...     ...
# 100285  2021-04-26       WIPRO.NS      475.7   479.4  483.85   477.0   482.0
# 100286  2021-04-27       WIPRO.NS      480.3   481.4   487.0   481.0  483.85
# 100287  2021-04-28       WIPRO.NS     485.05  485.85   493.2  481.25  488.65
# 100288  2021-04-29       WIPRO.NS      489.3   492.7   492.8   485.7   489.0
# 100289  2021-04-30       WIPRO.NS     489.85   491.5   511.8   489.3   492.5
#
# ...

# %%
stock.shape
# Out:
# (100290, 11)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stock['Prev Close'] = pd.to_numeric(stock['Prev Close'], errors='coerce')

# %%
stock['Open'] = pd.to_numeric(stock['Open'], errors='coerce')

# %%
stock['High'] = pd.to_numeric(stock['High'], errors='coerce')

# %%
stock['Low'] = pd.to_numeric(stock['Low'], errors='coerce')

# %%
stock['Last'] = pd.to_numeric(stock['Last'], errors='coerce')

# %%
stock['Close'] = pd.to_numeric(stock['Close'], errors='coerce')

# %%
stock['VWAP'] = pd.to_numeric(stock['VWAP'], errors='coerce')

# %%
stock['Volume'] = pd.to_numeric(stock['Volume'], errors='coerce')

# %%
stock['Turnover'] = pd.to_numeric(stock['Turnover'], errors='coerce')

# %%
selected_attributes = ['Prev Close', 'Open', 'High', 'Low','Last','Close','VWAP','Volume','Turnover']
# Create a new DataFrame with only the selected attributes
stock_selected = stock[selected_attributes]
# Calculate correlation matrix
corr = stock_selected.corr()
# Create a heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(corr, annot=True,  fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100290 entries, 0 to 100289
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Date        100290 non-null  object
#  1   Symbol      100290 non-null  object
#  2   Prev Close  100270 non-null  float64
#  3   Open        100270 non-null  float64
#  4   High        100270 non-null  float64
#  5   Low         100270 non-null  float64
#  6   Last        100270 non-null  float64
#  7   Close       100270 non-null  float64
#  8   VWAP        100270 non-null  float64
#  9   Volume      100270 non-null  float64
#  10  Turnover    100270 non-null  float64
# dtypes: float64(9), object(2)
# memory usage: 8.4+ MB

# %%
stock.shape
# Out:
# (100290, 11)

# %%
stock.describe()
# Out:
#           Prev Close           Open           High            Low  \
# count  100270.000000  100270.000000  100270.000000  100270.000000
# mean     1223.964567    1225.318462    1243.125711    1206.169175
# std      1748.077962    1750.502235    1773.166242    1725.279606
# min        22.150000      21.000000      23.700000      21.000000
# 25%       324.650000     325.000000     329.900000     319.550000
# 50%       649.375000     650.000000     660.050000     639.275000
# 75%      1370.875000    1371.000000    1391.675000    1350.000000
# max     18732.700000   18844.000000   18844.000000   18520.000000
#
#                 Last          Close           VWAP        Volume      Turnover
# count  100270.000000  100270.000000  100270.000000  1.002700e+05  1.002700e+05
# mean     1224.211570    1224.253439    1224.744685  3.414218e+06  2.097121e+14
# std      1748.462386    1748.568373    1749.161005  7.912414e+06  3.972547e+14
# ...

# %%
correlation = stock['Close'].corr(stock['High'])
print(correlation)
# Out:
# 0.9998310594828677

# %%
correlation = stock['Close'].corr(stock['Low'])
print(correlation)
# Out:
# 0.9998186774070623

# %%
correlation = stock['Close'].corr(stock['Prev Close'])
print(correlation)
# Out:
# 0.9992349989517072

# %%
#stock['P/E'] = (stock['Prev Close']+stock['High'])/stock['Low']

# %%
#stock['P/E']

# %%
#correlation = stock['Close'].corr(stock['P/E'])
#print(correlation)

# %%
stock['Symbol'].value_counts()
# Out:
# Symbol
# HDFCBANK.NS       5306
# CIPLA.NS          5306
# TATASTEEL.NS      5306
# TATAMOTORS.NS     5306
# RELIANCE.NS       5306
# ITC.NS            5306
# INFY              5306
# ICICIBANK.NS      5306
# HDFCBANK          5306
# WIPRO.NS          5306
# AXISBANK.NS       5306
# ASIANPAINT.NS     5306
# BRITANNIA.NS      5305
# HCLTECH.NS        5300
# TCS.NS            4139
# NTPC.NS           4088
# ADANIPORTS.NS     3322
# BAJAJ-AUTO.NS     3202
# BAJAJFINSV        3201
# NESTLEINDIA.NS    2806
# BAJAJFINSV.NS     2624
# BAJFINANCE.NS     2611
# Symbol              20
# Name: count, dtype: int64

# %%
correlation = stock['Close'].corr(stock['VWAP'])
print(correlation)
# Out:
# 0.9999492187343316

# %%
correlation = stock['Close'].corr(stock['Open'])
print(correlation)
# Out:
# 0.9996756042356106

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
sns.scatterplot(x='Close', y='High', data=stock)

# Add labels and title to the plot
plt.xlabel('Closing Price')
plt.ylabel('High')
plt.title('Scatter Plot between Closing Price and High')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
sns.scatterplot(x='Close', y='Prev Close', data=stock)

# Add labels and title to the plot
plt.xlabel('Closing Price')
plt.ylabel('Prev Close')
plt.title('Scatter Plot between Closing Price and Previous day closing')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
sns.scatterplot(x='Low', y='Close', data=stock)

# Add labels and title to the plot
plt.xlabel('Closing Price')
plt.ylabel('Low')
plt.title('Scatter Plot between Closing Price and Low')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
sns.scatterplot(x='Close', y='Last', data=stock)

# Add labels and title to the plot
plt.xlabel('Closing Price')
plt.ylabel('Last')
plt.title('Scatter Plot between Closing Price and Last')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
sns.scatterplot(x='Close', y='VWAP', data=stock)

# Add labels and title to the plot
plt.xlabel('Closing Price')
plt.ylabel('VWAP')
plt.title('Scatter Plot between Closing Price and VWAP')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
sns.scatterplot(x='Close', y='Open', data=stock)

# Add labels and title to the plot
plt.xlabel('Closing Price')
plt.ylabel('Open')
plt.title('Scatter Plot between Closing Price and Open')

# Show the plot
plt.show()

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100290 entries, 0 to 100289
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Date        100290 non-null  object
#  1   Symbol      100290 non-null  object
#  2   Prev Close  100270 non-null  float64
#  3   Open        100270 non-null  float64
#  4   High        100270 non-null  float64
#  5   Low         100270 non-null  float64
#  6   Last        100270 non-null  float64
#  7   Close       100270 non-null  float64
#  8   VWAP        100270 non-null  float64
#  9   Volume      100270 non-null  float64
#  10  Turnover    100270 non-null  float64
# dtypes: float64(9), object(2)
# memory usage: 8.4+ MB

# %%
sns.distplot(stock['Close'])
# Out:
# /var/folders/s2/mfnbj4cx45vdmhkh7vx2lcyw0000gn/T/ipykernel_2730/1271319782.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(stock['Close'])
# <Axes: xlabel='Close', ylabel='Density'>

# %%
sns.barplot(x=stock['Symbol'],y=stock['Close'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# /Users/aviralkhandelwal/anaconda3/lib/python3.11/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /Users/aviralkhandelwal/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,

# %%
stock['Symbol'].value_counts()
# Out:
# Symbol
# HDFCBANK.NS       5306
# CIPLA.NS          5306
# TATASTEEL.NS      5306
# TATAMOTORS.NS     5306
# RELIANCE.NS       5306
# ITC.NS            5306
# INFY              5306
# ICICIBANK.NS      5306
# HDFCBANK          5306
# WIPRO.NS          5306
# AXISBANK.NS       5306
# ASIANPAINT.NS     5306
# BRITANNIA.NS      5305
# HCLTECH.NS        5300
# TCS.NS            4139
# NTPC.NS           4088
# ADANIPORTS.NS     3322
# BAJAJ-AUTO.NS     3202
# BAJAJFINSV        3201
# NESTLEINDIA.NS    2806
# BAJAJFINSV.NS     2624
# BAJFINANCE.NS     2611
# Symbol              20
# Name: count, dtype: int64

# %%
symbol_counts = stock['Symbol'].value_counts()

# Filter symbols with count greater than or equal to 20
symbols_to_keep = symbol_counts[symbol_counts >= 20].index.tolist()

# Filter the DataFrame based on symbols to keep
stock = stock[stock['Symbol'].isin(symbols_to_keep)]

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100290 entries, 0 to 100289
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Date        100290 non-null  object
#  1   Symbol      100290 non-null  object
#  2   Prev Close  100270 non-null  float64
#  3   Open        100270 non-null  float64
#  4   High        100270 non-null  float64
#  5   Low         100270 non-null  float64
#  6   Last        100270 non-null  float64
#  7   Close       100270 non-null  float64
#  8   VWAP        100270 non-null  float64
#  9   Volume      100270 non-null  float64
#  10  Turnover    100270 non-null  float64
# dtypes: float64(9), object(2)
# memory usage: 8.4+ MB

# %%
stock['Symbol'].value_counts()
# Out:
# Symbol
# HDFCBANK.NS       5306
# CIPLA.NS          5306
# TATASTEEL.NS      5306
# TATAMOTORS.NS     5306
# RELIANCE.NS       5306
# ITC.NS            5306
# INFY              5306
# ICICIBANK.NS      5306
# HDFCBANK          5306
# WIPRO.NS          5306
# AXISBANK.NS       5306
# ASIANPAINT.NS     5306
# BRITANNIA.NS      5305
# HCLTECH.NS        5300
# TCS.NS            4139
# NTPC.NS           4088
# ADANIPORTS.NS     3322
# BAJAJ-AUTO.NS     3202
# BAJAJFINSV        3201
# NESTLEINDIA.NS    2806
# BAJAJFINSV.NS     2624
# BAJFINANCE.NS     2611
# Symbol              20
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a bar plot after handling missing values
sns.barplot(x=stock['Symbol'], y=stock['Close'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# /Users/aviralkhandelwal/anaconda3/lib/python3.11/site-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# /Users/aviralkhandelwal/anaconda3/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,

# %%
stock.describe()
# Out:
#           Prev Close           Open           High            Low  \
# count  100270.000000  100270.000000  100270.000000  100270.000000
# mean     1223.964567    1225.318462    1243.125711    1206.169175
# std      1748.077962    1750.502235    1773.166242    1725.279606
# min        22.150000      21.000000      23.700000      21.000000
# 25%       324.650000     325.000000     329.900000     319.550000
# 50%       649.375000     650.000000     660.050000     639.275000
# 75%      1370.875000    1371.000000    1391.675000    1350.000000
# max     18732.700000   18844.000000   18844.000000   18520.000000
#
#                 Last          Close           VWAP        Volume      Turnover
# count  100270.000000  100270.000000  100270.000000  1.002700e+05  1.002700e+05
# mean     1224.211570    1224.253439    1224.744685  3.414218e+06  2.097121e+14
# std      1748.462386    1748.568373    1749.161005  7.912414e+06  3.972547e+14
# ...

# %%
stock.isnull().sum()
# Out:
# Date           0
# Symbol         0
# Prev Close    20
# Open          20
# High          20
# Low           20
# Last          20
# Close         20
# VWAP          20
# Volume        20
# Turnover      20
# dtype: int64

# %%
stock = stock.dropna()

# %%
stock.iloc[10000]
# Out:
# Date               2005-06-16
# Symbol            AXISBANK.NS
# Prev Close             232.05
# Open                    234.9
# High                    236.0
# Low                     228.8
# Last                    228.8
# Close                  230.35
# VWAP                   232.25
# Volume               378929.0
# Turnover      8800601540000.0
# Name: 10002, dtype: object

# %%
stock.drop(columns=['Date','Volume','Turnover'],inplace=True)

# %%
y=stock['Close']

# %%
X=stock.drop(columns=['Close'])

# %%
X['Prev Close'] = X['Prev Close'].astype(float)
X['Open'] = X['Open'].astype(float)
X['High'] = X['High'].astype(float)
X['Low'] = X['Low'].astype(float)
X['Last'] = X['Last'].astype(float)
X['VWAP'] = X['VWAP'].astype(float)

# %%
#y['Close'] = y['Close'].astype(float)

# %%
X
# Out:
#                Symbol  Prev Close    Open     High     Low    Last    VWAP
# 0       ADANIPORTS.NS      440.00  770.00  1050.00  770.00  959.00  984.72
# 1       ADANIPORTS.NS      962.90  984.00   990.00  874.00  885.00  941.38
# 2       ADANIPORTS.NS      893.90  909.00   914.75  841.00  887.00  888.09
# 3       ADANIPORTS.NS      884.20  890.00   958.00  890.00  929.00  929.17
# 4       ADANIPORTS.NS      921.55  939.75   995.00  922.00  980.00  965.65
# ...               ...         ...     ...      ...     ...     ...     ...
# 100285       WIPRO.NS      475.70  479.40   483.85  477.00  482.00  479.77
# 100286       WIPRO.NS      480.30  481.40   487.00  481.00  483.85  484.07
# 100287       WIPRO.NS      485.05  485.85   493.20  481.25  488.65  487.55
# 100288       WIPRO.NS      489.30  492.70   492.80  485.70  489.00  489.45
# 100289       WIPRO.NS      489.85  491.50   511.80  489.30  492.50  501.42
#
# [100270 rows x 7 columns]

# %%
y
# Out:
# 0         962.90
# 1         893.90
# 2         884.20
# 3         921.55
# 4         969.30
#            ...
# 100285    480.30
# 100286    485.05
# 100287    489.30
# 100288    489.85
# 100289    492.75
# Name: Close, Length: 100270, dtype: float64

# %%
X.isnull().sum()
# Out:
# Symbol        0
# Prev Close    0
# Open          0
# High          0
# Low           0
# Last          0
# VWAP          0
# dtype: int64

# %%
y.isnull().sum()
# Out:
# 0

# %%
X = X.dropna()

# %%
y = y.dropna()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#                Symbol  Prev Close     Open    High      Low     Last     VWAP
# 90614    TATASTEEL.NS      319.40   325.45   326.3   315.05   317.20   321.66
# 4592    ASIANPAINT.NS      318.15   318.00   325.0   316.00   320.00   319.91
# 30929        CIPLA.NS      929.65   957.00   957.0   890.00   926.00   910.80
# 69287  NESTLEINDIA.NS     7214.45  7220.00  7220.0  7100.00  7115.00  7128.64
# 63090          ITC.NS      784.85   781.30   786.0   760.10   765.25   773.08
# ...               ...         ...      ...     ...      ...      ...      ...
# 6266    ASIANPAINT.NS     3171.75  3101.10  3179.5  2626.85  3150.00  3141.17
# 54897    ICICIBANK.NS     1016.35  1007.75  1014.0   992.00  1012.80  1002.44
# 76836     RELIANCE.NS     1739.05  1711.00  1773.9  1683.20  1751.00  1730.33
# 860     ADANIPORTS.NS      149.90   149.90   153.4   149.15   152.30   151.81
# 15798   BAJAJ-AUTO.NS     2447.85  2458.00  2515.0  2452.00  2480.50  2489.54
#
# [70189 rows x 7 columns]

# %%
y_train
# Out:
# 90614     317.40
# 4592      320.80
# 30929     924.70
# 69287    7113.05
# 63090     764.10
#           ...
# 6266     3146.40
# 54897    1010.15
# 76836    1752.90
# 860       151.80
# 15798    2479.25
# Name: Close, Length: 70189, dtype: float64

# %%
X_test
# Out:
#               Symbol  Prev Close     Open     High      Low     Last     VWAP
# 80033    RELIANCE.NS     1911.70  1917.80  1932.00  1899.65  1921.95  1916.93
# 1322   ADANIPORTS.NS      128.05   126.05   133.75   125.75   131.75   131.41
# 13078    AXISBANK.NS      540.40   534.95   548.95   532.45   547.25   541.56
# 63976         ITC.NS     1294.30  1291.00  1314.85  1291.00  1309.50  1306.45
# 60194           INFY     3113.35  3125.00  3145.00  3089.10  3100.00  3122.77
# ...              ...         ...      ...      ...      ...      ...      ...
# 14122  BAJAJ-AUTO.NS      493.85   487.00   511.85   487.00   508.00   507.61
# 1326   ADANIPORTS.NS      147.15   147.85   149.80   144.50   145.00   147.76
# 22541  BAJFINANCE.NS       59.05    57.60    59.00    57.55    57.55    58.01
# 9426     AXISBANK.NS       40.55    40.75    40.75    38.95    39.35    39.44
# 10564    AXISBANK.NS      650.00   646.00   661.50   641.00   654.65   652.93
#
# [30081 rows x 7 columns]

# %%
y_test
# Out:
# 80033    1919.90
# 1322      131.40
# 13078     544.80
# 63976    1310.75
# 60194    3100.30
#           ...
# 14122     509.95
# 1326      146.05
# 22541      57.95
# 9426       39.05
# 10564     658.65
# Name: Close, Length: 30081, dtype: float64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100270 entries, 0 to 100289
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Symbol      100270 non-null  object
#  1   Prev Close  100270 non-null  float64
#  2   Open        100270 non-null  float64
#  3   High        100270 non-null  float64
#  4   Low         100270 non-null  float64
#  5   Last        100270 non-null  float64
#  6   VWAP        100270 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 6.1+ MB

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 100270 entries, 0 to 100289
# Series name: Close
# Non-Null Count   Dtype
# --------------   -----
# 100270 non-null  float64
# dtypes: float64(1)
# memory usage: 1.5 MB

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder , StandardScaler
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred =pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.9999882242124358
# MAE 2.58356748425407
# /Users/aviralkhandelwal/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
import pickle

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
pickle.dump(stock,open('stock.pkl','wb'))

# %%
x = [['RELIANCE.NS',1911.70,1917.80,1932.00,1899.65,1921.95,1916.93]]

# %%
out = pipe.predict(x)
# Out:
# /Users/aviralkhandelwal/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
print(out)
# Out:
# [1920.8851089]
